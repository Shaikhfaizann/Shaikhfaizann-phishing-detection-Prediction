# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Dell\Downloads\dataset_phishing - dataset_phishing\Data\Preprocess.csv")

# %%
def extract_features(url):
    return {
        'url_length': len(url),
        'num_dots': url.count('.'),
        'has_https': int('https' in url),
        'has_at_symbol': int('@' in url),
        'has_hyphen': int('-' in url),
        'has_ip': int(any(char.isdigit() for char in url.split('/')[2]) if '://' in url else False)
    }

features_df = pd.DataFrame(df['url'].apply(extract_features).tolist())

# %%
df.drop(columns=['url'])
# Out:
#        length_url  length_hostname        ip    nb_dots  nb_hyphens     nb_at  \
# 0       -0.436327        -0.193964 -0.421020   0.379116   -0.477984 -0.142915
# 1        0.287067         0.177207  2.375182  -1.081136   -0.477984 -0.142915
# 2        1.173224         2.682613  2.375182   1.109242    0.001174 -0.142915
# 3       -0.779940        -0.936306 -0.421020  -0.351010   -0.477984 -0.142915
# 4       -0.110800        -0.565135 -0.421020  -0.351010    0.480332 -0.142915
# ...           ...              ...       ...        ...         ...       ...
# 11425   -0.291649        -0.379549 -0.421020  -0.351010   -0.477984 -0.142915
# 11426    0.413661        -0.286757 -0.421020   1.839369   -0.477984  6.288241
# 11427    0.793442        -0.472342  2.375182  -0.351010    2.396963 -0.142915
# 11428   -0.418243         0.826757 -0.421020  -0.351010   -0.477984 -0.142915
# 11429    7.521007        -0.657928  2.375182  15.711766   -0.477984  6.288241
#
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X_url = vectorizer.fit_transform(df['url'])  # returns a sparse matrix

# Combine with other features
from scipy.sparse import hstack
X = hstack([X_url])

# %%
import os

# %%
os.makedirs(r"C:\Users\Dell\Downloads\dataset_phishing - dataset_phishing\Data\convert_string_to_float",exist_ok=True)

# %%
df.to_csv(r"C:\Users\Dell\Downloads\dataset_phishing - dataset_phishing\Data\convert_string_to_float.csv",index=False)
